# %%
import numpy as np
import pandas as pd

# %%
magnitude_data = pd.read_csv("magnitude.csv")

# %%
magnitude_data = magnitude_data[['Latitude', 'Longitude', 'Magnitude']]
magnitude_data.head()
# Out:
#    Latitude  Longitude  Magnitude
# 0    19.246    145.616        6.0
# 1     1.863    127.352        5.8
# 2   -20.579   -173.972        6.2
# 3   -59.076    -23.557        5.8
# 4    11.938    126.427        5.8

# %%
magnitude_data = pd.get_dummies(magnitude_data)
magnitude_data.head()
# Out:
#    Latitude  Longitude  Magnitude
# 0    19.246    145.616        6.0
# 1     1.863    127.352        5.8
# 2   -20.579   -173.972        6.2
# 3   -59.076    -23.557        5.8
# 4    11.938    126.427        5.8

# %%
from sklearn.model_selection import train_test_split

X=magnitude_data.drop('Magnitude', axis=1) 
y=magnitude_data.Magnitude  

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train.head()
y_train.head()
# Out:
# 20551    6.1
# 18487    5.6
# 6022     5.5
# 13228    5.5
# 12207    5.5
# Name: Magnitude, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(X_test)

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#        Actual  Predicted
# 19516     6.3   5.893707
# 21679     5.9   5.922902
# 22492     6.1   5.899324
# 13744     5.6   5.899594
# 20565     6.2   5.914234
# ...       ...        ...
# 4304      5.7   5.893570
# 651       5.8   5.919580
# 16957     5.6   5.903192
# 20951     5.7   5.893764
# 4990      7.1   5.895875
#
# [7024 rows x 2 columns]

# %%
from joblib import dump, load
dump(regressor, 'magnitude_model.joblib')
# Out:
# ['magnitude_model.joblib']
